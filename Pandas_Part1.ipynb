# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')
pd.options.display.max_columns=None

# %%
df=pd.read_excel('CustomerChurn.xlsx')

# %% [markdown]
# # inspection

# %%
df.head()
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
# 2     326527  3668-QPYBK             No      No         No       2
# 3     845894  7795-CFOCW             No      No         No      45
# 4     503388  9237-HQITU             No      No         No       2
#
#   Phone Service    Multiple Lines Internet Service Online Security  \
# 0            No  No phone service              DSL              No
# 1           Yes                No              DSL             Yes
# 2           Yes                No              DSL             Yes
# 3            No  No phone service              DSL             Yes
# 4           Yes                No      Fiber optic              No
#
#   Online Backup Device Protection Tech Support Streaming TV Streaming Movies  \
# 0           Yes                No           No           No               No
# ...

# %%
df.tail()
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  \
# 7038           Yes               Yes              DSL             Yes
# 7039           Yes               Yes      Fiber optic              No
# 7040            No  No phone service              DSL             Yes
# 7041           Yes               Yes      Fiber optic              No
# 7042           Yes                No      Fiber optic             Yes
#
#      Online Backup Device Protection Tech Support Streaming TV  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LoyaltyID          7043 non-null   int64
#  1   Customer ID        7043 non-null   object
#  2   Senior Citizen     7043 non-null   object
#  3   Partner            7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   Tenure             7043 non-null   int64
#  6   Phone Service      7043 non-null   object
#  7   Multiple Lines     7043 non-null   object
#  8   Internet Service   7043 non-null   object
#  9   Online Security    7043 non-null   object
#  10  Online Backup      7043 non-null   object
#  11  Device Protection  7043 non-null   object
#  12  Tech Support       7043 non-null   object
#  13  Streaming TV       7043 non-null   object
#  14  Streaming Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
# ...

# %%
df.shape,df.shape[0],df.shape[1]
# Out:
# ((7043, 21), 7043, 21)

# %%
df.describe()
# Out:
#            LoyaltyID       Tenure  Monthly Charges
# count    7043.000000  7043.000000      7043.000000
# mean   550382.651001    32.371149        64.761692
# std    260776.118690    24.559481        30.090047
# min    100346.000000     0.000000        18.250000
# 25%    323604.500000     9.000000        35.500000
# 50%    548704.000000    29.000000        70.350000
# 75%    776869.000000    55.000000        89.850000
# max    999912.000000    72.000000       118.750000

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
df.columns.str.contains('Streaming')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True,  True, False, False, False,
#        False, False, False])

# %%
df.columns[df.columns.str.contains('Streaming')]
# Out:
# Index(['Streaming TV', 'Streaming Movies'], dtype='object')

# %%
df.columns[df.columns.str.startswith('C')]
# Out:
# Index(['Customer ID', 'Contract', 'Churn'], dtype='object')

# %% [markdown]
# # subsetting

# %%
df.LoyaltyID.head()
# Out:
# 0    318537
# 1    152148
# 2    326527
# 3    845894
# 4    503388
# Name: LoyaltyID, dtype: int64

# %%
df['Customer ID'].head()
# Out:
# 0    7590-VHVEG
# 1    5575-GNVDE
# 2    3668-QPYBK
# 3    7795-CFOCW
# 4    9237-HQITU
# Name: Customer ID, dtype: object

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
x=[1,2,3,4]
type(x)
# Out:
# list

# %%
df[['Senior Citizen', 'Partner', 'Dependents']].head()
# Out:
#   Senior Citizen Partner Dependents
# 0             No     Yes         No
# 1             No      No         No
# 2             No      No         No
# 3             No      No         No
# 4             No      No         No

# %%
df.columns[df.columns.str.contains('i')].to_list()
# Out:
# ['Senior Citizen',
#  'Phone Service',
#  'Multiple Lines',
#  'Internet Service',
#  'Online Security',
#  'Online Backup',
#  'Device Protection',
#  'Streaming TV',
#  'Streaming Movies',
#  'Paperless Billing']

# %%
df[['Phone Service', 'Multiple Lines', 'Internet Service',
       'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
       'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing']].head()
# Out:
#   Phone Service    Multiple Lines Internet Service Online Security  \
# 0            No  No phone service              DSL              No
# 1           Yes                No              DSL             Yes
# 2           Yes                No              DSL             Yes
# 3            No  No phone service              DSL             Yes
# 4           Yes                No      Fiber optic              No
#
#   Online Backup Device Protection Tech Support Streaming TV Streaming Movies  \
# 0           Yes                No           No           No               No
# 1            No               Yes           No           No               No
# 2           Yes                No           No           No               No
# 3            No               Yes          Yes           No               No
# 4            No                No           No           No               No
#
#          Contract Paperless Billing
# 0  Month-to-month               Yes
# ...

# %%
df.loc[:,'Phone Service':'Paperless Billing'].head()
# Out:
#   Phone Service    Multiple Lines Internet Service Online Security  \
# 0            No  No phone service              DSL              No
# 1           Yes                No              DSL             Yes
# 2           Yes                No              DSL             Yes
# 3            No  No phone service              DSL             Yes
# 4           Yes                No      Fiber optic              No
#
#   Online Backup Device Protection Tech Support Streaming TV Streaming Movies  \
# 0           Yes                No           No           No               No
# 1            No               Yes           No           No               No
# 2           Yes                No           No           No               No
# 3            No               Yes          Yes           No               No
# 4            No                No           No           No               No
#
#          Contract Paperless Billing
# 0  Month-to-month               Yes
# ...

# %%
df.head()
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
# 2     326527  3668-QPYBK             No      No         No       2
# 3     845894  7795-CFOCW             No      No         No      45
# 4     503388  9237-HQITU             No      No         No       2
#
#   Phone Service    Multiple Lines Internet Service Online Security  \
# 0            No  No phone service              DSL              No
# 1           Yes                No              DSL             Yes
# 2           Yes                No              DSL             Yes
# 3            No  No phone service              DSL             Yes
# 4           Yes                No      Fiber optic              No
#
#   Online Backup Device Protection Tech Support Streaming TV Streaming Movies  \
# 0           Yes                No           No           No               No
# ...

# %%
df.iloc[4,5]
# Out:
# 2

# %% [markdown]
# ## value_counts()

# %%
df['Senior Citizen'].value_counts(ascending=True)
# Out:
# Yes    1142
# No     5901
# Name: Senior Citizen, dtype: int64

# %%
df['Senior Citizen'].value_counts(normalize=True,dropna=False)
# Out:
# No     0.837853
# Yes    0.162147
# Name: Senior Citizen, dtype: float64

# %% [markdown]
# ## booleanCoditions

# %%
df[df['Senior Citizen']=='Yes']
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 20       352579  8779-QRDMV            Yes      No         No       1
# 30       203287  3841-NFECX            Yes     Yes         No      71
# 31       480074  4929-XIHVW            Yes     Yes         No       2
# 34       486672  3413-BMNZE            Yes      No         No       1
# 50       498491  8012-SOUDQ            Yes      No         No      43
# ...         ...         ...            ...     ...        ...     ...
# 7023     818769  1035-IPQPU            Yes     Yes         No      63
# 7029     695438  2235-DWLJU            Yes      No         No       6
# 7031     847238  3605-JISKB            Yes     Yes         No      55
# 7032     137858  6894-LFHLY            Yes      No         No       1
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
#
#      Phone Service    Multiple Lines Internet Service Online Security  \
# ...

# %%
df[df['Senior Citizen']=='Yes']['Senior Citizen'].value_counts()
# Out:
# Yes    1142
# Name: Senior Citizen, dtype: int64

# %%
df[(df['Senior Citizen']=='Yes') & (df.Dependents=='Yes') & (df.Tenure<=10)].shape
# Out:
# (9, 21)

# %%
df[(df['Multiple Lines']=='Yes') & (df['Online Security']=='Yes') & (df.Tenure<=50)].shape
# Out:
# (362, 21)

# %%
df[(df['Multiple Lines']=='Yes') & (df['Online Security']=='Yes') & (df.Tenure<=50)][['Customer ID','LoyaltyID']]
# Out:
#      Customer ID  LoyaltyID
# 44    4080-IIARD     128608
# 52    6575-SUVOI     221059
# 95    8637-XJIVR     960651
# 117   5299-RULOA     194722
# 141   4080-OGPJL     385977
# ...          ...        ...
# 6975  1904-WAJAA     381674
# 6987  5981-ZVXOT     347217
# 6989  1389-WNUIB     594516
# 7024  7398-LXGYX     358421
# 7038  6840-RESVB     810338
#
# [362 rows x 2 columns]

# %%
df[df.Tenure<20][['Customer ID','Tenure']]
# Out:
#      Customer ID  Tenure
# 0     7590-VHVEG       1
# 2     3668-QPYBK       2
# 4     9237-HQITU       2
# 5     9305-CDSKC       8
# 7     6713-OKOMC      10
# ...          ...     ...
# 7032  6894-LFHLY       1
# 7035  8456-QDAVC      19
# 7036  7750-EYXWZ      12
# 7040  4801-JZAZL      11
# 7041  8361-LTMKD       4
#
# [2807 rows x 2 columns]

# %% [markdown]
# # sortingDF

# %%
df1=df[['Customer ID', 'Senior Citizen', 'Partner','Tenure']]
df2=df[['Customer ID','Online Backup', 'Device Protection', 'Tech Support',
       'Streaming TV', 'Streaming Movies']]

# %%
df1.head()
# Out:
#   Customer ID Senior Citizen Partner  Tenure
# 0  7590-VHVEG             No     Yes       1
# 1  5575-GNVDE             No      No      34
# 2  3668-QPYBK             No      No       2
# 3  7795-CFOCW             No      No      45
# 4  9237-HQITU             No      No       2

# %%
df2.head()
# Out:
#   Customer ID Online Backup Device Protection Tech Support Streaming TV  \
# 0  7590-VHVEG           Yes                No           No           No
# 1  5575-GNVDE            No               Yes           No           No
# 2  3668-QPYBK           Yes                No           No           No
# 3  7795-CFOCW            No               Yes          Yes           No
# 4  9237-HQITU            No                No           No           No
#
#   Streaming Movies
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No

# %%
df1.sort_values(by='Tenure')
# Out:
#      Customer ID Senior Citizen Partner  Tenure
# 1340  1371-DWPAZ             No     Yes       0
# 936   5709-LVOEQ             No     Yes       0
# 6670  4075-WKNIU             No     Yes       0
# 4380  2520-SGTTA             No     Yes       0
# 5218  2923-ARZLG             No     Yes       0
# ...          ...            ...     ...     ...
# 914   6024-RUGGH             No     Yes      72
# 917   4079-WWQQQ             No      No      72
# 4574  8999-XXGNS            Yes     Yes      72
# 3635  5296-PSYVW             No     Yes      72
# 3543  0853-TWRVK             No     Yes      72
#
# [7043 rows x 4 columns]

# %%
df1.sort_values(by='Tenure',ascending=False)
# Out:
#      Customer ID Senior Citizen Partner  Tenure
# 1672  4737-AQCPU             No     Yes      72
# 193   9680-NIAUV             No     Yes      72
# 4553  5914-XRFQB             No     Yes      72
# 483   5168-MQQCA             No     Yes      72
# 3266  0464-WJTKO             No     Yes      72
# ...          ...            ...     ...     ...
# 1082  4367-NUYAO             No     Yes       0
# 3826  3213-VVOLG             No     Yes       0
# 936   5709-LVOEQ             No     Yes       0
# 6754  2775-SEFEE             No      No       0
# 1340  1371-DWPAZ             No     Yes       0
#
# [7043 rows x 4 columns]

# %%
df1.sort_values(by=['Senior Citizen','Tenure'])
# Out:
#      Customer ID Senior Citizen Partner  Tenure
# 488   4472-LVYGI             No     Yes       0
# 753   3115-CZMZD             No      No       0
# 936   5709-LVOEQ             No     Yes       0
# 1082  4367-NUYAO             No     Yes       0
# 1340  1371-DWPAZ             No     Yes       0
# ...          ...            ...     ...     ...
# 6477  3518-FSTWG            Yes     Yes      72
# 6601  4909-JOUPP            Yes     Yes      72
# 6629  6437-UDQJM            Yes     Yes      72
# 6707  2452-MRMZF            Yes     Yes      72
# 7007  2274-XUATA            Yes     Yes      72
#
# [7043 rows x 4 columns]

# %%
df1.sort_values(by=['Senior Citizen','Tenure']).head(n=20)
# Out:
#      Customer ID Senior Citizen Partner  Tenure
# 488   4472-LVYGI             No     Yes       0
# 753   3115-CZMZD             No      No       0
# 936   5709-LVOEQ             No     Yes       0
# 1082  4367-NUYAO             No     Yes       0
# 1340  1371-DWPAZ             No     Yes       0
# 3331  7644-OMVMY             No     Yes       0
# 3826  3213-VVOLG             No     Yes       0
# 4380  2520-SGTTA             No     Yes       0
# 5218  2923-ARZLG             No     Yes       0
# 6670  4075-WKNIU             No     Yes       0
# 6754  2775-SEFEE             No      No       0
# 0     7590-VHVEG             No     Yes       1
# 22    1066-JKSGK             No      No       1
# 27    8665-UTDHZ             No     Yes       1
# 33    7310-EGVHZ             No      No       1
# 70    2273-QCKXA             No      No       1
# 80    5919-TMRGD             No      No       1
# 100   6380-ARCEH             No      No       1
# 101   3679-XASPY             No     Yes       1
# ...

# %%
df1.sort_values(by=['Senior Citizen','Tenure'],ascending=[False,True]).head(n=20)
# Out:
#      Customer ID Senior Citizen Partner  Tenure
# 20    8779-QRDMV            Yes      No       1
# 34    3413-BMNZE            Yes      No       1
# 91    2424-WVHPL            Yes      No       1
# 139   0390-DCFDQ            Yes     Yes       1
# 252   9514-JDSKI            Yes     Yes       1
# 345   0021-IKXGC            Yes      No       1
# 419   5564-NEMQO            Yes      No       1
# 585   5192-EBGOV            Yes      No       1
# 915   6513-EECDB            Yes     Yes       1
# 1325  7206-GZCDC            Yes      No       1
# 1334  1768-ZAIFU            Yes      No       1
# 1371  6567-HOOPW            Yes      No       1
# 1505  5240-IJOQT            Yes      No       1
# 1513  0661-XEYAN            Yes      No       1
# 1600  3068-OMWZA            Yes      No       1
# 1651  8580-AECUZ            Yes      No       1
# 1670  5047-LHVLY            Yes      No       1
# 1731  8375-DKEBR            Yes      No       1
# 1834  8080-DDEMJ            Yes      No       1
# ...

# %% [markdown]
# # addingColumns

# %%
df['newlyAddedColumn']=df['Monthly Charges']/10

# %%
df[['Monthly Charges','newlyAddedColumn']].head(10)
# Out:
#    Monthly Charges  newlyAddedColumn
# 0            29.85             2.985
# 1            56.95             5.695
# 2            53.85             5.385
# 3            42.30             4.230
# 4            70.70             7.070
# 5            99.65             9.965
# 6            89.10             8.910
# 7            29.75             2.975
# 8           104.80            10.480
# 9            56.15             5.615

# %%
df3=df.drop('newlyAddedColumn',axis=1)
#axis=1 is columns
#axis=0 is rows/records/observastions

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn',
#        'newlyAddedColumn'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn',
#        'newlyAddedColumn'],
#       dtype='object')

# %%
df.drop('newlyAddedColumn',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
df.drop('Monthly Charges',axis=1)
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0        318537  7590-VHVEG             No     Yes         No       1
# 1        152148  5575-GNVDE             No      No         No      34
# 2        326527  3668-QPYBK             No      No         No       2
# 3        845894  7795-CFOCW             No      No         No      45
# 4        503388  9237-HQITU             No      No         No       2
# ...         ...         ...            ...     ...        ...     ...
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  \
# ...
